# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
reward = pd.read_csv("check.csv")
return_1 = reward.index[1:600].to_list()
results = list(map(float, return_1))
# reward.iloc[:,0]
# print(reward)
plt.plot(results)
plt.show()

# %%
test = np.loadtxt("v3.txt")
plt.plot(test)
